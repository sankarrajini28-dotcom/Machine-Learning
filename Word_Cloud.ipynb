# %%
# !pip install wordcloud
from wordcloud import WordCloud
import matplotlib.pyplot as plt

text = "data data data analysis analysis visualization visual python code python machine learning learning art design cloud words word text text text big data insights graphic information digital project creative web research metrics statistics trends system modern software development programming"

wc = WordCloud(background_color="Gray")
wc.generate(text)

plt.imshow(wc)
plt.axis("off")
plt.show()
