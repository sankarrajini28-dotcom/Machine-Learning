# %%
import numpy as np
import pandas as pd

# %%
# Task 1 -student study hours vs marks

# %%
# Loading dataset
st=pd.read_csv("student_exam_data_v1.csv")
st
# Out:
#      study_hours  exam_score
# 0            4.4          59
# 1            9.6          98
# 2            7.6          82
# 3            6.4          69
# 4            2.4          42
# ..           ...         ...
# 495          4.2          55
# 496          6.3          69
# 497          1.7          44
# 498          9.8          95
# 499          9.9          99
#
# [500 rows x 2 columns]

# %%
st.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 500 entries, 0 to 499
# Data columns (total 2 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   study_hours  500 non-null    float64
#  1   exam_score   500 non-null    int64
# dtypes: float64(1), int64(1)
# memory usage: 7.9 KB

# %%
# Displaying first 5 rows
st.head()
# Out:
#    study_hours  exam_score
# 0          4.4          59
# 1          9.6          98
# 2          7.6          82
# 3          6.4          69
# 4          2.4          42

# %%
# checking missing values
st.isnull().sum()
# Out:
# study_hours    0
# exam_score     0
# dtype: int64

# %%
x=st["study_hours"].value_counts()
x
# Out:
# study_hours
# 9.7    13
# 1.8    13
# 6.7    12
# 3.9    11
# 9.1    11
#        ..
# 9.3     2
# 5.3     2
# 8.6     2
# 2.2     1
# 4.6     1
# Name: count, Length: 90, dtype: int64

# %%
y=st["exam_score"].value_counts()
y
# Out:
# exam_score
# 79    17
# 45    17
# 83    16
# 89    12
# 74    12
#       ..
# 32     3
# 46     3
# 99     2
# 98     1
# 96     1
# Name: count, Length: 68, dtype: int64

# %%
# Feature engineering

# Feature(independent variable)
x=st[['study_hours']]
# Target(dependent variable)
y=st[['exam_score']]

# %%
# Dataset split into train and test data
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,train_size=0.7,random_state=42)

# %%
# Linear regression
from sklearn.linear_model import LinearRegression
L=LinearRegression()
L.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
# Prediction
y_prediction=L.predict(x_test)
y_prediction
# Out:
# array([[73.94009125],
#        [83.87427562],
#        [39.50158542],
#        [50.09804875],
#        [89.83478624],
#        [56.05855937],
#        [36.85246959],
#        [49.43576979],
#        [40.16386438],
#        [81.88743875],
#        [77.913765  ],
#        [56.05855937],
#        [58.70767521],
#        [54.0717225 ],
#        [36.85246959],
#        [80.56288083],
#        [56.72083833],
#        [71.95325437],
#        [60.03223312],
#        [89.17250729],
#        [62.68134896],
#        [72.61553333],
#        [88.51022833],
#        [36.85246959],
#        [81.22515979],
#        [73.94009125],
#        [40.16386438],
#        [76.58920708],
#        [73.27781229],
#        [38.1770275 ],
#        [94.47073895],
#        [86.52339145],
#        [40.82614333],
#        [48.77349083],
#        [79.23832291],
#        [42.15070125],
#        [40.82614333],
#        [81.88743875],
#        [44.79981708],
#        [56.72083833],
#        [79.23832291],
# ...

# %%
y_test
# Out:
#      exam_score
# 361          71
# 73           80
# 374          38
# 155          47
# 104          89
# ..          ...
# 266          76
# 23           59
# 222          36
# 261          94
# 426          66
#
# [150 rows x 1 columns]

# %%
from sklearn.metrics import r2_score,mean_absolute_error, mean_squared_error

# Accuracy of prediction

R2=r2_score(y_test,y_prediction)
mae = mean_absolute_error(y_test, y_prediction)
mse= mean_squared_error(y_test, y_prediction)
rmse = np.sqrt(mean_squared_error(y_test, y_prediction))

print("Accuracy",R2)
print("MAE",mae)
print("MSE",mse)
print("RMSE",rmse)
# Out:
# Accuracy 0.9684862125086858
# MAE 2.5718551467217927
# MSE 9.75936478690736
# RMSE 3.123998205330368

# %%
# Task 2

# %%
ad=pd.read_csv("/content/Advertising Budget and Sales.csv")
ad
# Out:
#      Unnamed: 0  TV Ad Budget ($)  Radio Ad Budget ($)  \
# 0             1             230.1                 37.8
# 1             2              44.5                 39.3
# 2             3              17.2                 45.9
# 3             4             151.5                 41.3
# 4             5             180.8                 10.8
# ..          ...               ...                  ...
# 195         196              38.2                  3.7
# 196         197              94.2                  4.9
# 197         198             177.0                  9.3
# 198         199             283.6                 42.0
# 199         200             232.1                  8.6
#
#      Newspaper Ad Budget ($)  Sales ($)
# 0                       69.2       22.1
# 1                       45.1       10.4
# 2                       69.3        9.3
# 3                       58.5       18.5
# 4                       58.4       12.9
# ..                       ...        ...
# ...

# %%
ad.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 200 entries, 0 to 199
# Data columns (total 5 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Unnamed: 0               200 non-null    int64
#  1   TV Ad Budget ($)         200 non-null    float64
#  2   Radio Ad Budget ($)      200 non-null    float64
#  3   Newspaper Ad Budget ($)  200 non-null    float64
#  4   Sales ($)                200 non-null    float64
# dtypes: float64(4), int64(1)
# memory usage: 7.9 KB

# %%
ad.columns
# Out:
# Index(['Unnamed: 0', 'TV Ad Budget ($)', 'Radio Ad Budget ($)',
#        'Newspaper Ad Budget ($)', 'Sales ($)'],
#       dtype='object')

# %%
ad.isnull().sum()
# Out:
# Unnamed: 0                 0
# TV Ad Budget ($)           0
# Radio Ad Budget ($)        0
# Newspaper Ad Budget ($)    0
# Sales ($)                  0
# dtype: int64

# %%
ad=ad.drop("Unnamed: 0",axis=1)
ad
# Out:
#      TV Ad Budget ($)  Radio Ad Budget ($)  Newspaper Ad Budget ($)  Sales ($)
# 0               230.1                 37.8                     69.2       22.1
# 1                44.5                 39.3                     45.1       10.4
# 2                17.2                 45.9                     69.3        9.3
# 3               151.5                 41.3                     58.5       18.5
# 4               180.8                 10.8                     58.4       12.9
# ..                ...                  ...                      ...        ...
# 195              38.2                  3.7                     13.8        7.6
# 196              94.2                  4.9                      8.1        9.7
# 197             177.0                  9.3                      6.4       12.8
# 198             283.6                 42.0                     66.2       25.5
# 199             232.1                  8.6                      8.7       13.4
#
# [200 rows x 4 columns]

# %%
ad=ad.rename(columns={"TV Ad Budget ($)":"TV",
                      "Radio Ad Budget ($)":"Radio",
                      "Newspaper Ad Budget ($)":"Newspaper",
                      "Sales ($)":"Sales"})
ad
# Out:
#         TV  Radio  Newspaper  Sales
# 0    230.1   37.8       69.2   22.1
# 1     44.5   39.3       45.1   10.4
# 2     17.2   45.9       69.3    9.3
# 3    151.5   41.3       58.5   18.5
# 4    180.8   10.8       58.4   12.9
# ..     ...    ...        ...    ...
# 195   38.2    3.7       13.8    7.6
# 196   94.2    4.9        8.1    9.7
# 197  177.0    9.3        6.4   12.8
# 198  283.6   42.0       66.2   25.5
# 199  232.1    8.6        8.7   13.4
#
# [200 rows x 4 columns]

# %%
# Feature engineering

# independent Variables
x1=ad[['TV','Radio','Newspaper']] # Feture

# dependent variable
y1=ad[['Sales']]  # Target

# %%
from sklearn.model_selection import train_test_split

# %%
x1_train,x1_test,y1_train,y1_test=train_test_split(x1,y1,test_size=0.2,random_state=42)

# %%
from sklearn.linear_model import LinearRegression
add=LinearRegression()
add.fit(x1_train,y1_train)
# Out:
# LinearRegression()

# %%
y1_prediction=add.predict(x1_test)
y1_prediction
# Out:
# array([[16.4080242 ],
#        [20.88988209],
#        [21.55384318],
#        [10.60850256],
#        [22.11237326],
#        [13.10559172],
#        [21.05719192],
#        [ 7.46101034],
#        [13.60634581],
#        [15.15506967],
#        [ 9.04831992],
#        [ 6.65328312],
#        [14.34554487],
#        [ 8.90349333],
#        [ 9.68959028],
#        [12.16494386],
#        [ 8.73628397],
#        [16.26507258],
#        [10.27759582],
#        [18.83109103],
#        [19.56036653],
#        [13.25103464],
#        [12.33620695],
#        [21.30695132],
#        [ 7.82740305],
#        [ 5.80957448],
#        [20.75753231],
#        [11.98138077],
#        [ 9.18349576],
#        [ 8.5066991 ],
#        [12.46646769],
#        [10.00337695],
#        [21.3876709 ],
#        [12.24966368],
#        [18.26661538],
#        [20.13766267],
#        [14.05514005],
#        [20.85411186],
#        [11.0174441 ],
#        [ 4.56899622]])

# %%
# actual value
y1_test
# Out:
#      Sales
# 95    16.9
# 15    22.4
# 30    21.4
# 158    7.3
# 128   24.7
# 115   12.6
# 69    22.3
# 170    8.4
# 174   11.5
# 45    14.9
# 66     9.5
# 182    8.7
# 165   11.9
# 78     5.3
# 186   10.3
# 177   11.7
# 56     5.5
# 152   16.6
# 82    11.3
# 68    18.9
# 124   19.7
# 16    12.5
# 148   10.9
# 93    22.2
# 65     9.3
# 60     8.1
# 84    21.7
# 67    13.4
# 125   10.6
# 132    5.7
# 9     10.6
# 18    11.3
# 55    23.7
# 75     8.7
# 150   16.1
# 104   20.7
# 135   11.6
# 137   20.8
# 164   11.9
# 76     6.9

# %%
# Accuracy of prediction
from sklearn.metrics import r2_score,mean_squared_error
r2_score(y1_test,y1_prediction)
# Out:
# 0.899438024100912

# %%
print("R² Score:", r2_score(y1_test, y1_prediction))
print("Mean Squared Error:", mean_squared_error(y1_test, y1_prediction))
# Out:
# R² Score: 0.899438024100912
# Mean Squared Error: 3.1740973539761033

# %%
new_data = pd.DataFrame({
    'TV': [150],
    'Radio': [25],
    'Newspaper': [30]
})
new_data
# Out:
#     TV  Radio  Newspaper
# 0  150     25         30

# %%
predicted_sales = add.predict(new_data)
print("Predicted Sales:", predicted_sales[0])
# Out:
# Predicted Sales: [14.50120474]

# %%
# Task 3-Ice cream sales prediction
ice=pd.read_csv("/content/Ice Cream Sales - temperatures.csv")
ice
# Out:
#      Temperature  Ice Cream Profits
# 0             39              13.17
# 1             40              11.88
# 2             41              18.82
# 3             42              18.65
# 4             43              17.02
# ..           ...                ...
# 360           99              85.13
# 361           99              87.08
# 362           99              89.29
# 363          101              81.91
# 364          101              85.02
#
# [365 rows x 2 columns]

# %%
ice.isnull().sum()
# Out:
# Temperature          0
# Ice Cream Profits    0
# dtype: int64

# %%
ice['Temperature'] = (ice['Temperature'] - 32) * 5/9
ice
# Out:
#      Temperature  Ice Cream Profits
# 0       3.888889              13.17
# 1       4.444444              11.88
# 2       5.000000              18.82
# 3       5.555556              18.65
# 4       6.111111              17.02
# ..           ...                ...
# 360    37.222222              85.13
# 361    37.222222              87.08
# 362    37.222222              89.29
# 363    38.333333              81.91
# 364    38.333333              85.02
#
# [365 rows x 2 columns]

# %%
# split data into train data and test data
x2_train, x2_test, y2_train, y2_test = train_test_split(
    x2, y2, test_size=0.2, random_state=42
)

# %%
# Features (Independent Variable)
x2 = ice[['Temperature']]

# Target (Dependent Variable)
y2 = ice[['Ice Cream Profits']]

# %%
# Build Linear Regression Model
from sklearn.linear_model import LinearRegression
model = LinearRegression()
model.fit(x2_train, y2_train)
# Out:
# LinearRegression()

# %%
# Predict sales when Temperature = 35°C
temp = pd.DataFrame({'Temperature': [35]})
predicted_sales = model.predict(temp)

print("Predicted Ice Cream Sales at 35°C:", predicted_sales[0])
# Out:
# Predicted Ice Cream Sales at 35°C: [79.40363409]

# %%
import matplotlib.pyplot as plt

# Draw Regression Line
plt.figure(figsize=(8,5))
plt.scatter(x2, y2, color='blue', label='Actual Data')
plt.plot(x2, model.predict(x2), color='red', linewidth=2, label='Regression Line')

# %%
# Highlight predicted point
plt.scatter(35, predicted_sales[0], color='green', s=100, label='Prediction (35°C)')

plt.title("Temperature vs Ice Cream Sales")
plt.xlabel("Temperature (°C)")
plt.ylabel("Ice Cream Sales")
plt.legend()
plt.grid(True)
plt.show()

# %%
# Task-4 Laptop price prediction

# %%
lap=pd.read_csv("/content/laptop_master.csv")
lap
# Out:
#      source   brand                       processor  \
# 0      ds01      HP       5th Gen AMD Ryzen 5 5600H
# 1      ds01      HP    12th Gen Intel Core i3 1215U
# 2      ds01    Acer   11th Gen Intel Core i3 1115G4
# 3      ds01  Lenovo    12th Gen Intel Core i5 1240P
# 4      ds01   Apple                        Apple M1
# ...     ...     ...                             ...
# 3913   ds04  Lenovo  13th Gen Intel Core i9 13900HX
# 3914   ds04  Lenovo    12th Gen Intel Core i7 1255U
# 3915   ds04  Lenovo    12th Gen Intel Core i3 1215U
# 3916   ds04      HP       6th Gen AMD Ryzen 7 6800H
# 3917   ds04      LG       7th Gen AMD Ryzen 7 7730U
#
#                                gpu  ram_gb ram_type  storage_gb storage_type  \
# 0          4GB AMD Radeon RX 6500M       8     DDR4         512          SSD
# 1               Intel UHD Graphics       8     DDR4         512          SSD
# 2           Intel Iris Xe Graphics       8     DDR4         512          SSD
# ...

# %%
lap.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3918 entries, 0 to 3917
# Data columns (total 10 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   source        3918 non-null   object
#  1   brand         3918 non-null   object
#  2   processor     3918 non-null   object
#  3   gpu           3918 non-null   object
#  4   ram_gb        3918 non-null   int64
#  5   ram_type      3918 non-null   object
#  6   storage_gb    3918 non-null   int64
#  7   storage_type  3918 non-null   object
#  8   os            3918 non-null   object
#  9   price         3918 non-null   int64
# dtypes: int64(3), object(7)
# memory usage: 306.2+ KB

# %%
lap.columns
# Out:
# Index(['source', 'brand', 'processor', 'gpu', 'ram_gb', 'ram_type',
#        'storage_gb', 'storage_type', 'os', 'price'],
#       dtype='object')

# %%
lap=lap.drop(['source', 'brand', 'gpu', 'ram_type',
       'storage_gb', 'os'],axis="columns")
lap
# Out:
#                            processor  ram_gb storage_type   price
# 0          5th Gen AMD Ryzen 5 5600H       8          SSD   49900
# 1       12th Gen Intel Core i3 1215U       8          SSD   39900
# 2      11th Gen Intel Core i3 1115G4       8          SSD   26990
# 3       12th Gen Intel Core i5 1240P      16          SSD   59729
# 4                           Apple M1       8          SSD   69990
# ...                              ...     ...          ...     ...
# 3913  13th Gen Intel Core i9 13900HX      32          SSD  286200
# 3914    12th Gen Intel Core i7 1255U      16          SSD   91000
# 3915    12th Gen Intel Core i3 1215U       8          SSD   29620
# 3916       6th Gen AMD Ryzen 7 6800H      16          SSD   87670
# 3917       7th Gen AMD Ryzen 7 7730U      16          SSD   89799
#
# [3918 rows x 4 columns]

# %%
lap.isnull().sum()
# Out:
# processor       0
# ram_gb          0
# storage_type    0
# price           0
# dtype: int64

# %%
lap.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3918 entries, 0 to 3917
# Data columns (total 4 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   processor     3918 non-null   object
#  1   ram_gb        3918 non-null   int64
#  2   storage_type  3918 non-null   object
#  3   price         3918 non-null   int64
# dtypes: int64(2), object(2)
# memory usage: 122.6+ KB

# %%
lap.select_dtypes(include="object")
# Out:
#                            processor storage_type
# 0          5th Gen AMD Ryzen 5 5600H          SSD
# 1       12th Gen Intel Core i3 1215U          SSD
# 2      11th Gen Intel Core i3 1115G4          SSD
# 3       12th Gen Intel Core i5 1240P          SSD
# 4                           Apple M1          SSD
# ...                              ...          ...
# 3913  13th Gen Intel Core i9 13900HX          SSD
# 3914    12th Gen Intel Core i7 1255U          SSD
# 3915    12th Gen Intel Core i3 1215U          SSD
# 3916       6th Gen AMD Ryzen 7 6800H          SSD
# 3917       7th Gen AMD Ryzen 7 7730U          SSD
#
# [3918 rows x 2 columns]

# %%
lap['storage_type'].value_counts()
# Out:
# storage_type
# SSD     3510
# HDD      401
# eMMC       7
# Name: count, dtype: int64

# %%
lap['storage_type'] = lap['storage_type'].map({
    'SSD': 1,
    'HDD': 2,
    'eMMC': 3
})

print(lap.head())
# Out:
#                        processor  ram_gb  storage_type  price
# 0      5th Gen AMD Ryzen 5 5600H       8           NaN  49900
# 1   12th Gen Intel Core i3 1215U       8           NaN  39900
# 2  11th Gen Intel Core i3 1115G4       8           NaN  26990
# 3   12th Gen Intel Core i5 1240P      16           NaN  59729
# 4                       Apple M1       8           NaN  69990

# %%
lap['storage_type'] = (lap['storage_type'] == 'SSD').astype(int)

print(lap.head())
# Out:
#                        processor  ram_gb  storage_type  price
# 0      5th Gen AMD Ryzen 5 5600H       8             0  49900
# 1   12th Gen Intel Core i3 1215U       8             0  39900
# 2  11th Gen Intel Core i3 1115G4       8             0  26990
# 3   12th Gen Intel Core i5 1240P      16             0  59729
# 4                       Apple M1       8             0  69990
