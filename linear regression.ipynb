# %%
import pandas as pd
s=pd.read_csv('Salary_Data.csv')
s
# Out:
#     YearsExperience  Salary
# 0               1.1   39343
# 1               1.3   46205
# 2               1.5   37731
# 3               2.0   43525
# 4               2.2   39891
# 5               2.9   56642
# 6               3.0   60150
# 7               3.2   54445
# 8               3.2   64445
# 9               3.7   57189
# 10              3.9   63218
# 11              4.0   55794
# 12              4.0   56957
# 13              4.1   57081
# 14              4.5   61111
# 15              4.9   67938
# 16              5.1   66029
# 17              5.3   83088
# 18              5.9   81363
# 19              6.0   93940
# 20              6.8   91738
# 21              7.1   98273
# 22              7.9  101302
# 23              8.2  113812
# 24              8.7  109431
# 25              9.0  105582
# 26              9.5  116969
# 27              9.6  112635
# 28             10.3  122391
# 29             10.5  121872

# %%
s.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30 entries, 0 to 29
# Data columns (total 2 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   YearsExperience  30 non-null     float64
#  1   Salary           30 non-null     int64
# dtypes: float64(1), int64(1)
# memory usage: 612.0 bytes

# %%
s.isnull()
# Out:
#     YearsExperience  Salary
# 0             False   False
# 1             False   False
# 2             False   False
# 3             False   False
# 4             False   False
# 5             False   False
# 6             False   False
# 7             False   False
# 8             False   False
# 9             False   False
# 10            False   False
# 11            False   False
# 12            False   False
# 13            False   False
# 14            False   False
# 15            False   False
# 16            False   False
# 17            False   False
# 18            False   False
# 19            False   False
# 20            False   False
# 21            False   False
# 22            False   False
# 23            False   False
# 24            False   False
# 25            False   False
# 26            False   False
# 27            False   False
# 28            False   False
# 29            False   False

# %%
s['YearsExperience'].value_counts()
# Out:
# YearsExperience
# 3.2     2
# 4.0     2
# 1.1     1
# 5.3     1
# 10.3    1
# 9.6     1
# 9.5     1
# 9.0     1
# 8.7     1
# 8.2     1
# 7.9     1
# 7.1     1
# 6.8     1
# 6.0     1
# 5.9     1
# 5.1     1
# 1.3     1
# 4.9     1
# 4.5     1
# 4.1     1
# 3.9     1
# 3.7     1
# 3.0     1
# 2.9     1
# 2.2     1
# 2.0     1
# 1.5     1
# 10.5    1
# Name: count, dtype: int64

# %%
pip install scikit-learn
# Out:
# Requirement already satisfied: scikit-learn in c:\users\pradeepa\anaconda3\lib\site-packages (1.7.2)
# Requirement already satisfied: numpy>=1.22.0 in c:\users\pradeepa\anaconda3\lib\site-packages (from scikit-learn) (2.3.5)
# Requirement already satisfied: scipy>=1.8.0 in c:\users\pradeepa\anaconda3\lib\site-packages (from scikit-learn) (1.16.3)
# Requirement already satisfied: joblib>=1.2.0 in c:\users\pradeepa\anaconda3\lib\site-packages (from scikit-learn) (1.5.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in c:\users\pradeepa\anaconda3\lib\site-packages (from scikit-learn) (3.5.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
from sklearn.linear_model import LinearRegression

# %%
ir=LinearRegression()

# %%
x=s[['YearsExperience']]
y=s[['Salary']]
print(x)
print(y)
# Out:
#     YearsExperience
# 0               1.1
# 1               1.3
# 2               1.5
# 3               2.0
# 4               2.2
# 5               2.9
# 6               3.0
# 7               3.2
# 8               3.2
# 9               3.7
# 10              3.9
# 11              4.0
# 12              4.0
# 13              4.1
# 14              4.5
# 15              4.9
# 16              5.1
# 17              5.3
# 18              5.9
# 19              6.0
# 20              6.8
# 21              7.1
# 22              7.9
# 23              8.2
# 24              8.7
# 25              9.0
# 26              9.5
# 27              9.6
# 28             10.3
# 29             10.5
#     Salary
# 0    39343
# 1    46205
# 2    37731
# 3    43525
# 4    39891
# 5    56642
# 6    60150
# 7    54445
# 8    64445
# 9    57189
# 10   63218
# 11   55794
# 12   56957
# 13   57081
# 14   61111
# 15   67938
# 16   66029
# 17   83088
# 18   81363
# 19   93940
# 20   91738
# 21   98273
# 22  101302
# 23  113812
# 24  109431
# 25  105582
# 26  116969
# 27  112635
# 28  122391
# 29  121872

# %%
from sklearn.model_selection import train_test_split

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,train_size=0.7,random_state=42)
x_train
# Out:
#     YearsExperience
# 0               1.1
# 4               2.2
# 16              5.1
# 5               2.9
# 13              4.1
# 11              4.0
# 22              7.9
# 1               1.3
# 2               1.5
# 25              9.0
# 3               2.0
# 21              7.1
# 26              9.5
# 18              5.9
# 29             10.5
# 20              6.8
# 7               3.2
# 10              3.9
# 14              4.5
# 19              6.0
# 6               3.0

# %%
x_test
# Out:
#     YearsExperience
# 27              9.6
# 15              4.9
# 23              8.2
# 17              5.3
# 8               3.2
# 9               3.7
# 28             10.3
# 24              8.7
# 12              4.0

# %%
ir=LinearRegression()
ir.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
y_pred=ir.predict(x_test)
y_pred
# Out:
# array([[115573.62288352],
#        [ 71679.93878159],
#        [102498.90847018],
#        [ 75415.57147111],
#        [ 55803.4998511 ],
#        [ 60473.04071301],
#        [122110.98009019],
#        [107168.44933209],
#        [ 63274.76523015]])

# %%
y_test
# Out:
#     Salary
# 27  112635
# 15   67938
# 23  113812
# 17   83088
# 8    64445
# 9    57189
# 28  122391
# 24  109431
# 12   56957

# %%
import numpy as np
ir.predict(np.array([[3.3]]))
# Out:
# C:\Users\pradeepa\anaconda3\Lib\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([[56737.40802348]])

# %%
from sklearn.metrics import r2_score
r2=r2_score(y_test,y_pred)
r2
# Out:
# 0.9414466227178214

# %%
import matplotlib.pyplot as plt

plt.scatter(x_train,y_train, color='red')

# %%
import pandas as pd
h=pd.read_csv('student_dataset_10000_rows.csv')
h
# Out:
#       study_hours  attendance  sleep_hours  internet_usage  \
# 0               7          56            8               7
# 1               4          69            5               3
# 2              11          60            7               6
# 3               8          99            9               8
# 4               5          52            8               6
# ...           ...         ...          ...             ...
# 9995            2          58            9               7
# 9996            7          98            6               9
# 9997           10          44            8               5
# 9998           10          75            7               5
# 9999            2          70            6              11
#
#       assignments_completed  previous_score  exam_score placement_status
# 0                        10              62      100.00           Placed
# 1                         8              56      100.00           Placed
# 2                        10              45      100.00           Placed
# 3                         4              55       90.17           Placed
# 4                         8              40       78.82           Placed
# ...                     ...             ...         ...              ...
# 9995                      8              88       69.31       Not Placed
# 9996                      4              87      100.00           Placed
# 9997                     10              37       95.94           Placed
# 9998                      8              52       88.61           Placed
# 9999                     16              52       78.96           Placed
#
# [10000 rows x 8 columns]

# %%
h.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 8 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   study_hours            10000 non-null  int64
#  1   attendance             10000 non-null  int64
#  2   sleep_hours            10000 non-null  int64
#  3   internet_usage         10000 non-null  int64
#  4   assignments_completed  10000 non-null  int64
#  5   previous_score         10000 non-null  int64
#  6   exam_score             10000 non-null  float64
#  7   placement_status       10000 non-null  object
# dtypes: float64(1), int64(6), object(1)
# memory usage: 625.1+ KB

# %%
h.drop('placement_status',axis='columns')
# Out:
#       study_hours  attendance  sleep_hours  internet_usage  \
# 0               7          56            8               7
# 1               4          69            5               3
# 2              11          60            7               6
# 3               8          99            9               8
# 4               5          52            8               6
# ...           ...         ...          ...             ...
# 9995            2          58            9               7
# 9996            7          98            6               9
# 9997           10          44            8               5
# 9998           10          75            7               5
# 9999            2          70            6              11
#
#       assignments_completed  previous_score  exam_score
# 0                        10              62      100.00
# 1                         8              56      100.00
# 2                        10              45      100.00
# 3                         4              55       90.17
# 4                         8              40       78.82
# ...                     ...             ...         ...
# 9995                      8              88       69.31
# 9996                      4              87      100.00
# 9997                     10              37       95.94
# 9998                      8              52       88.61
# 9999                     16              52       78.96
#
# [10000 rows x 7 columns]

# %%
h.isnull()
# Out:
#       study_hours  attendance  sleep_hours  internet_usage  \
# 0           False       False        False           False
# 1           False       False        False           False
# 2           False       False        False           False
# 3           False       False        False           False
# 4           False       False        False           False
# ...           ...         ...          ...             ...
# 9995        False       False        False           False
# 9996        False       False        False           False
# 9997        False       False        False           False
# 9998        False       False        False           False
# 9999        False       False        False           False
#
#       assignments_completed  previous_score  exam_score  placement_status
# 0                     False           False       False             False
# 1                     False           False       False             False
# 2                     False           False       False             False
# 3                     False           False       False             False
# 4                     False           False       False             False
# ...                     ...             ...         ...               ...
# 9995                  False           False       False             False
# 9996                  False           False       False             False
# 9997                  False           False       False             False
# 9998                  False           False       False             False
# 9999                  False           False       False             False
#
# [10000 rows x 8 columns]

# %%
pip install scikit-learn
# Out:
# Requirement already satisfied: scikit-learn in c:\users\pradeepa\anaconda3\lib\site-packages (1.7.2)
# Requirement already satisfied: numpy>=1.22.0 in c:\users\pradeepa\anaconda3\lib\site-packages (from scikit-learn) (2.3.5)
# Requirement already satisfied: scipy>=1.8.0 in c:\users\pradeepa\anaconda3\lib\site-packages (from scikit-learn) (1.16.3)
# Requirement already satisfied: joblib>=1.2.0 in c:\users\pradeepa\anaconda3\lib\site-packages (from scikit-learn) (1.5.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in c:\users\pradeepa\anaconda3\lib\site-packages (from scikit-learn) (3.5.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
from sklearn.linear_model import LinearRegression

# %%
e=LinearRegression()

# %%
x=h[['study_hours']]
y=h[['exam_score']]
print(x)
print(y)
# Out:
#       study_hours
# 0               7
# 1               4
# 2              11
# 3               8
# 4               5
# ...           ...
# 9995            2
# 9996            7
# 9997           10
# 9998           10
# 9999            2
#
# [10000 rows x 1 columns]
#       exam_score
# 0         100.00
# 1         100.00
# 2         100.00
# 3          90.17
# 4          78.82
# ...          ...
# 9995       69.31
# 9996      100.00
# 9997       95.94
# 9998       88.61
# 9999       78.96
#
# [10000 rows x 1 columns]

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,train_size=0.7,random_state=42)
x_train
# Out:
#       study_hours
# 9069           11
# 2603            6
# 7738            6
# 1579            8
# 5058            2
# ...           ...
# 5734           11
# 5191            7
# 5390            9
# 860             1
# 7270            1
#
# [7000 rows x 1 columns]

# %%
x_test
# Out:
#       study_hours
# 6252            8
# 4684            6
# 1731            8
# 4742            1
# 4521           10
# ...           ...
# 8014            1
# 1074           11
# 3063            3
# 6487            7
# 4705            6
#
# [3000 rows x 1 columns]

# %%
e=LinearRegression()
e.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
import numpy as np
e.predict(np.array([[1]]))
# Out:
# C:\Users\pradeepa\anaconda3\Lib\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([[73.43923256]])

# %%
import matplotlib.pyplot as plt

plt.scatter(x_train,y_train, color='red')
