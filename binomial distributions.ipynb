# %%
#1. Online Shopping Delivery(n=12,p=0.9)
#An e-commerce company finds that 90% of orders are delivered on time.A manager randomly checks 12 orders.
#What is the probability that exactly 10 orders are delivered on time?
#What is the probability that at least 11 orders are delivered on time?
#What is the probability that fewer than 9 orders are delivered on time?
from scipy.stats import binom

# %%
binom.pmf(n=12,k=10,p=0.9)
# Out:
# np.float64(0.23012777046599997)

# %%
binom.pmf(p=0.9,k=11,n=12)
# Out:
# np.float64(0.3765727153080001)

# %%
binom.pmf(p=0.9,k=12,n=12)
# Out:
# np.float64(0.2824295364810001)

# %%
binom.cdf(p=0.9,k=8,n=12)
# Out:
# np.float64(0.02563747016499998)

# %%
#2. campus placement(n=15,p=0.65)
"""A college reports that 65% of students get placed.
A trainer selects 15 students.
Tasks:
Find the probability that exactly 12 students are placed.
Find the probability that at least 10 students are placed.
Find the expected number of students placed."""

# %%
a=binom.pmf(p=0.65,k=12,n=15)
b=binom.cdf(p=0.65,k=10,n=15)
print(a,b)
mean= 15*0.65
print(mean)
# Out:
# 0.11096239180419934 0.6480565722237327
# 9.75

# %%
#bank loan approval(p=0.7,k=20)
"""A bank approves 70% of loan applications.
An officer processes 20 applications.
Tasks:
What is the probability that exactly 16 loans are approved?
What is the probability that more than 18 loans are approved?
Calculate the mean and variance."""

# %%
a=binom.pmf(p=0.7,k=20,n=16)
b=binom.cdf(p=0.7,k=20,n=18)
print(a)
print(b)
mean=20*0.7
print(mean)
p=0.7
q=1-p
var=20*0.7*q
print(var)
# Out:
# 0.0
# 1.0
# 14.0
# 4.200000000000001

# %%
#cricket match(p=0.4,n=10)
"""A batsman has a 40% chance of hitting a boundary on any ball.
He faces 10 balls.
Tasks:
Find the probability of exactly 5 boundaries.
Find the probability of at least 7 boundaries.
Find the probability of no boundaries."""

# %%
a=binom.pmf(p=0.4,k=5,n=10)
b=binom.sf(p=0.4,k=7,n=10)
c=binom.pmf(p=0.4,k=0,n=10)
print(a)
print(b)
print(c)
# Out:
# 0.20065812479999992
# 0.012294553600000006
# 0.0060466175999999185

# %%
#manufacturing quality check(p=0.05,n=30)
"""A factory produces bulbs with a 5% defect rate.
An inspector checks 30 bulbs.
Tasks:
Find the probability of exactly 2 defective bulbs.
Find the probability that none are defective.
Find the probability of at least one defective bulb."""

# %%
a=binom.pmf(p=0.05,k=2,n=30)
b=binom.pmf(p=0.05,k=0,n=30)
c=1-binom.pmf(p=0.05,k=0,n=30)
print(a)
print(b)
print(c)
# Out:
# 0.25863673771517404
# 0.21463876394293752
# 0.7853612360570625

# %%
#email marketing(n=18,p=0.25)
"""A company knows that 25% of customers click a promotional email.
The company sends emails to 18 customers.
Tasks:
Find the probability that exactly 6 customers click.
Find the probability that at least 4 customers click.
Find the expected number of customers who click."""

# %%
a=binom.pmf(p=0.25,k=6,n=18)
b=binom.cdf(p=0.25,k=4,n=18)
mean=18*0.25
print(a)
print(b)
print(mean)
# Out:
# 0.1435644040466287
# 0.5186693304567598
# 4.5

# %%
#hospital vaccination(n=25,p=0.95)
"""A vaccine is effective in 95% of people.
Doctors observe 25 patients.
Tasks:
Find the probability that exactly 24 patients respond successfully.
Find the probability that all 25 respond successfully.
Find the probability that fewer than 23 respond successfully."""

# %%
a=binom.pmf(p=0.95,k=24,n=25)
b=binom.pmf(p=0.95,k=25,n=25)
c=binom.cdf(p=0.95,k=23,n=25)
print(a)
print(b)
print(c)
# Out:
# 0.3649862804234658
# 0.27738957312183377
# 0.3576241464547004

# %%
#software testing(n=20,p=0.92)
"""A software tester finds that 92% of test cases pass successfully.
A release contains 20 test cases.
Tasks:
What is the probability that exactly 18 test cases pass?
What is the probability that all test cases pass?
What is the probability that at least 19 test cases pass?"""

# %%
from scipy.stats import binom
a=binom.pmf(p=0.92,k=18,n=20)
b=binom.pmf(p=0.95,k=20,n=20)
c=binom.cdf(p=0.95,k=19,n=25)
print(a)
print(b)
print(c)
# Out:
# 0.2710906052244336
# 0.3584859224085419
# 0.001212961322097262

# %%
#student attendance(n=15,p=0.80)
"""The probability that a student attends class on a given day is 0.8.
A teacher records attendance for 15 students.
Tasks:
Find the probability that exactly 12 students attend.
Find the probability that more than 10 students attend.
Calculate the expected attendance."""
# Out:
# 0.25013889531904
# 0.9999990654461438
# 12.0

# %%
a=binom.pmf(p=0.80,k=12,n=15)
b=binom.sf(p=0.92,k=10,n=20)
mean=15*0.80
print(a)
print(b)
print(mean)
# Out:
# 0.25013889531904
# 0.9999990654461438
# 12.0

# %%
#mobile app installation(n=25,p=0.35)
"""An advertisement convinces 30% of users to install an app.
The ad is shown to 25 users.
Tasks:
Find the probability that exactly 8 users install the app.
Find the probability that at least 10 users install it.
Find the probability that fewer than 5 users install"""

# %%
a=binom.pmf(p=0.35,k=8,n=25)
b=binom.sf(p=0.35,k=10,n=25)
c=binom.cdf(p=0.35,k=5,n=25)
print(a)
print(b)
print(c)
# Out:
# 0.16074151526049393
# 0.22883875639141357
# 0.08262469719739138
